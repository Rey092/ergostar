# %%
import sqlalchemy  # noqa
from sqlalchemy import create_engine, select
engine = create_engine('sqlite:///:memory:', echo=False)
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %%
from src.features.users.models import UserModel
from src.features.auth.models import ApiKeyModel

# %%
statement = select(ApiKeyModel).where(ApiKeyModel.id == 1)

# %%
with engine.connect() as connection:
    result = connection.execute(statement)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[80], line 2
#       1 with engine.connect() as connection:
# ----> 2     result = connection.execute(statement)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1632, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1624 schema_translate_map = execution_options.get(
#    1625     "schema_translate_map", None
#    1626 )
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
# -> 1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    1635     column_keys=keys,
#    1636     for_executemany=for_executemany,
#    1637     schema_translate_map=schema_translate_map,
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
#    1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    (...)
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:703, in ClauseElement._compile_w_cache(self, dialect, compiled_cache, column_keys, for_executemany, schema_translate_map, **kw)
#     701 if compiled_sql is None:
#     702     cache_hit = dialect.CACHE_MISS
# --> 703     compiled_sql = self._compiler(
#     704         dialect,
#     705         cache_key=elem_cache_key,
#     706         column_keys=column_keys,
#     707         for_executemany=for_executemany,
#     708         schema_translate_map=schema_translate_map,
#     709         **kw,
#     710     )
#     711     compiled_cache[key] = compiled_sql
#     712 else:
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:316, in CompilerElement._compiler(self, dialect, **kw)
#     314 if TYPE_CHECKING:
#     315     assert isinstance(self, ClauseElement)
# --> 316 return dialect.statement_compiler(dialect, self, **kw)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/compiler.py:1429, in SQLCompiler.__init__(self, dialect, statement, cache_key, column_keys, for_executemany, linting, _supporting_against, **kwargs)
#    1426 self.truncated_names: Dict[Tuple[str, str], str] = {}
#    1427 self._truncated_counters: Dict[str, int] = {}
# -> 1429 Compiled.__init__(self, dialect, statement, **kwargs)
#    1431 if self.isinsert or self.isupdate or self.isdelete:
#    1432     if TYPE_CHECKING:
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/compiler.py:870, in Compiled.__init__(self, dialect, statement, schema_translate_map, render_schema_translate, compile_kwargs)
#     868         assert isinstance(statement, Executable)
#     869     self.execution_options = statement._execution_options
# --> 870 self.string = self.process(self.statement, **compile_kwargs)
#     872 if render_schema_translate:
#     873     self.string = self.preparer._render_schema_translates(
#     874         self.string, schema_translate_map
#     875     )
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/compiler.py:915, in Compiled.process(self, obj, **kwargs)
#     914 def process(self, obj: Visitable, **kwargs: Any) -> str:
# --> 915     return obj._compiler_dispatch(self, **kwargs)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/visitors.py:141, in Visitable._generate_compiler_dispatch.<locals>._compiler_dispatch(self, visitor, **kw)
#     139     return visitor.visit_unsupported_compilation(self, err, **kw)  # type: ignore  # noqa: E501
#     140 else:
# --> 141     return meth(self, **kw)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/compiler.py:4679, in SQLCompiler.visit_select(self, select_stmt, asfrom, insert_into, fromhints, compound_index, select_wraps_for, lateral, from_linter, **kwargs)
#    4671 # initial setup of SELECT.  the compile_state_factory may now
#    4672 # be creating a totally different SELECT from the one that was
#    4673 # passed in.  for ORM use this will convert from an ORM-state
#    4674 # SELECT to a regular "Core" SELECT.  other composed operations
#    4675 # such as computation of joins will be performed.
#    4677 kwargs["within_columns_clause"] = False
# -> 4679 compile_state = select_stmt._compile_state_factory(
#    4680     select_stmt, self, **kwargs
#    4681 )
#    4682 kwargs["ambiguous_table_name_map"] = (
#    4683     compile_state._ambiguous_table_name_map
#    4684 )
#    4686 select_stmt = compile_state.statement
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/sql/base.py:683, in CompileState.create_for_statement(cls, statement, compiler, **kw)
#     681     return cls(statement, compiler, **kw)
#     682 else:
# --> 683     return klass.create_for_statement(statement, compiler, **kw)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/context.py:1097, in ORMSelectCompileState.create_for_statement(cls, statement, compiler, **kw)
#    1089 # label_convention is stateful and will yield deduping keys if it
#    1090 # sees the same key twice.  therefore it's important that it is not
#    1091 # invoked for the above "memoized" entities that aren't actually
#    1092 # in the columns clause
#    1093 self._label_convention = self._column_naming_convention(
#    1094     statement._label_style, self.use_legacy_query_style
#    1095 )
# -> 1097 _QueryEntity.to_compile_state(
#    1098     self,
#    1099     select_statement._raw_columns,
#    1100     self._entities,
#    1101     is_current_entities=True,
#    1102 )
#    1104 self.current_path = select_statement._compile_options._current_path
#    1106 self.eager_order_by = ()
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/context.py:2552, in _QueryEntity.to_compile_state(cls, compile_state, entities, entities_collection, is_current_entities)
#    2550 if entity.is_selectable:
#    2551     if "parententity" in entity._annotations:
# -> 2552         _MapperEntity(
#    2553             compile_state,
#    2554             entity,
#    2555             entities_collection,
#    2556             is_current_entities,
#    2557         )
#    2558     else:
#    2559         _ColumnEntity._for_columns(
#    2560             compile_state,
#    2561             entity._select_iterable,
#    (...)
#    2564             is_current_entities,
#    2565         )
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/context.py:2632, in _MapperEntity.__init__(self, compile_state, entity, entities_collection, is_current_entities)
#    2629     compile_state._has_orm_entities = True
#    2631 entity = entity._annotations["parententity"]
# -> 2632 entity._post_inspect
#    2633 ext_info = self.entity_zero = entity
#    2634 entity = ext_info.entity
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:1253, in HasMemoized.memoized_attribute.__get__(self, obj, cls)
#    1251 if obj is None:
#    1252     return self
# -> 1253 obj.__dict__[self.__name__] = result = self.fget(obj)
#    1254 obj._memoized_keys |= {self.__name__}
#    1255 return result
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:2711, in Mapper._post_inspect(self)
#    2700 @HasMemoized.memoized_attribute
#    2701 def _post_inspect(self):
#    2702     """This hook is invoked by attribute inspection.
#    2703
#    2704     E.g. when Query calls:
#    (...)
#    2709
#    2710     """
# -> 2711     self._check_configure()
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:2388, in Mapper._check_configure(self)
#    2380 @util.langhelpers.tag_method_for_warnings(
#    2381     "This warning originated from the `configure_mappers()` process, "
#    2382     "which was invoked automatically in response to a user-initiated "
#    (...)
#    2385 )
#    2386 def _check_configure(self) -> None:
#    2387     if self.registry._new_mappers:
# -> 2388         _configure_registries({self.registry}, cascade=True)
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:4204, in _configure_registries(registries, cascade)
#    4198     Mapper.dispatch._for_class(Mapper).before_configured()  # type: ignore # noqa: E501
#    4199     # initialize properties on all mappers
#    4200     # note that _mapper_registry is unordered, which
#    4201     # may randomly conceal/reveal issues related to
#    4202     # the order of mapper compilation
# -> 4204     _do_configure_registries(registries, cascade)
#    4205 finally:
#    4206     _already_compiling = False
#
# File ~/github/ergostar/.venv/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:4241, in _do_configure_registries(registries, cascade)
#    4233     e = sa_exc.InvalidRequestError(
#    4234         "One or more mappers failed to initialize - "
#    4235         "can't proceed with initialization of other "
#    (...)
#    4238         % (mapper, mapper._configure_failed)
#    4239     )
#    4240     e._configure_failed = mapper._configure_failed  # type: ignore
# -> 4241     raise e
#    4243 if not mapper.configured:
#    4244     try:
#
# InvalidRequestError: One or more mappers failed to initialize - can't proceed with initialization of other mappers. Triggering mapper: 'Mapper[UserModel(users)]'. Original exception was: When initializing mapper Mapper[UserModel(users)], expression 'ApiKeyModel' failed to locate a name ('ApiKeyModel'). If this is a class name, consider adding this relationship() to the <class 'src.features.users.models.UserModel'> class after both dependent classes have been defined.
